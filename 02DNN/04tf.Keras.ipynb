# %% [markdown]
# # tf.keras API사용하기

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

print(tf.test.is_gpu_available())
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# False

# %% [markdown]
# ### Sequential 모델

# %%
## 랜덤한 회귀용 예제 데이터셋을 만듭니다

np.random.seed(0)

def make_random_data():
    x = np.random.uniform(low=-2, high=2, size=200)
    y = []
    for t in x:
        r = np.random.normal(loc=0.0, 
                             scale=(0.5 + t*t/3), 
                             size=None)
        y.append(r)
    return  x, 1.726*x -0.84 + np.array(y)


x, y = make_random_data() 

plt.plot(x, y, 'o')
plt.show()

# %%
# 훈련데이터 / 테스트 데이터 나누기
x_train, y_train = x[:150], y[:150]
x_test, y_test = x[150:], y[150:]

# %% [markdown]
# ### tf.keras Sequential 모델
#
# Sequential 모델은 순서대로 층을 쌓아 모형을 생성한다.
#
# * Dense 층은 완전 연결층이다.
#
# * 이 예제에서는 간단한 y = wx + b 형태의 회귀 모형을 구현한다. 1차원 데이터 셋으로 출력 유닛 하나를 가진 간단한 완전 연결층 하나를 추가한다.
#
# * 회귀모형이므로 마지막 출력층의 활성화 함수를 설정하지 않는다.
#
# * activation 파라미터의 기본은 None이다. sigmoid, tanh, relu를 지정 가능하다.

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Dense(units=1, input_dim=1))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 모형의 훈련
#
# **compile()메서드**
#
#
# * `loss = 'mean_squared_error'` 에서 회귀문제를 위해 평균제곱오차를 손실함수로 설정한다.
# * 참고) 다중 클래스 분류 문제를 위해서는 categorical_crossentropy, 이진 분류에서는 binary_crossentropy를 사용한다.
# * `optimizer=tf.keras.optimizers.SGD(0.001)` 경사하강법 옵티마이저를 정한다. SGD 이외에도 여러가지가 있다.
#
# * https://www.tensorflow.org/api_docs/python/tf/keras/optimizers

# %%
model.compile(loss='mean_squared_error',
             optimizer=tf.keras.optimizers.SGD(0.001))

#model.compile(optimizer='sgd', loss='mse')
#history = model.fit(x_train, y_train, epochs=100, 
#                    validation_split=0.3)

history = model.fit(x_train, y_train, epochs=100)
# Out:
# Train on 150 samples
# Epoch 1/100
# 150/150 [==============================] - 1s 4ms/sample - loss: 1.8269
# Epoch 2/100
# 150/150 [==============================] - 0s 55us/sample - loss: 1.8064
# Epoch 3/100
# 150/150 [==============================] - 0s 55us/sample - loss: 1.7867
# Epoch 4/100
# 150/150 [==============================] - 0s 54us/sample - loss: 1.7667
# Epoch 5/100
# 150/150 [==============================] - 0s 72us/sample - loss: 1.7469
# Epoch 6/100
# 150/150 [==============================] - 0s 73us/sample - loss: 1.7278
# Epoch 7/100
# 150/150 [==============================] - 0s 64us/sample - loss: 1.7088
# Epoch 8/100
# 150/150 [==============================] - 0s 66us/sample - loss: 1.6904
# Epoch 9/100
# 150/150 [==============================] - 0s 69us/sample - loss: 1.6712
# Epoch 10/100
# 150/150 [==============================] - 0s 51us/sample - loss: 1.6539
# Epoch 11/100
# 150/150 [==============================] - 0s 51us/sample - loss: 1.6368
# Epoch 12/100
# 150/150 [==============================] - 0s 63us/sample - loss: 1.6202
# Epoch 13/100
# 150/150 [==============================] - 0s 51us/sample - loss: 1.6033
# Epoch 14/100
# 150/150 [==============================] - 0s 61us/sample - loss: 1.5868
# Epoch 15/100
# 150/150 [==============================] - 0s 71us/sample - loss: 1.5709
# Epoch 16/100
# 150/150 [==============================] - 0s 60us/sample - loss: 1.5553
# Epoch 17/100
# 150/150 [==============================] - 0s 58us/sample - loss: 1.5401
# Epoch 18/100
# 150/150 [==============================] - 0s 57us/sample - loss: 1.5254
# Epoch 19/100
# 150/150 [==============================] - 0s 68us/sample - loss: 1.5106
# Epoch 20/100
# 150/150 [==============================] - 0s 64us/sample - loss: 1.4964
# Epoch 21/100
# 150/150 [==============================] - 0s 55us/sample - loss: 1.4821
# Epoch 22/100
# 150/150 [==============================] - 0s 59us/sample - loss: 1.4681
# Epoch 23/100
# 150/150 [==============================] - 0s 53us/sample - loss: 1.4549
# Epoch 24/100
# 150/150 [==============================] - 0s 50us/sample - loss: 1.4420
# Epoch 25/100
# 150/150 [==============================] - 0s 62us/sample - loss: 1.4283
# Epoch 26/100
# 150/150 [==============================] - 0s 67us/sample - loss: 1.4155
# Epoch 27/100
# 150/150 [==============================] - 0s 58us/sample - loss: 1.4030
# Epoch 28/100
# 150/150 [==============================] - 0s 66us/sample - loss: 1.3908
# Epoch 29/100
# 150/150 [==============================] - 0s 55us/sample - loss: 1.3789
# Epoch 30/100
# 150/150 [==============================] - 0s 97us/sample - loss: 1.3671
# Epoch 31/100
# 150/150 [==============================] - 0s 81us/sample - loss: 1.3559
# Epoch 32/100
# 150/150 [==============================] - 0s 74us/sample - loss: 1.3443
# Epoch 33/100
# 150/150 [==============================] - 0s 75us/sample - loss: 1.3333
# Epoch 34/100
# 150/150 [==============================] - 0s 70us/sample - loss: 1.3225
# Epoch 35/100
# 150/150 [==============================] - 0s 54us/sample - loss: 1.3116
# Epoch 36/100
# 150/150 [==============================] - 0s 63us/sample - loss: 1.3016
# Epoch 37/100
# 150/150 [==============================] - 0s 42us/sample - loss: 1.2916
# Epoch 38/100
# 150/150 [==============================] - 0s 67us/sample - loss: 1.2816
# Epoch 39/100
# 150/150 [==============================] - 0s 44us/sample - loss: 1.2714
# Epoch 40/100
# 150/150 [==============================] - 0s 62us/sample - loss: 1.2621
# Epoch 41/100
# 150/150 [==============================] - 0s 55us/sample - loss: 1.2525
# Epoch 42/100
# 150/150 [==============================] - 0s 54us/sample - loss: 1.2431
# Epoch 43/100
# 150/150 [==============================] - 0s 64us/sample - loss: 1.2341
# Epoch 44/100
# 150/150 [==============================] - 0s 58us/sample - loss: 1.2252
# Epoch 45/100
# 150/150 [==============================] - 0s 65us/sample - loss: 1.2165
# Epoch 46/100
# 150/150 [==============================] - 0s 51us/sample - loss: 1.2079
# Epoch 47/100
# 150/150 [==============================] - 0s 72us/sample - loss: 1.1993
# Epoch 48/100
# 150/150 [==============================] - 0s 57us/sample - loss: 1.1913
# Epoch 49/100
# 150/150 [==============================] - 0s 97us/sample - loss: 1.1835
# Epoch 50/100
# 150/150 [==============================] - 0s 55us/sample - loss: 1.1755
# Epoch 51/100
# 150/150 [==============================] - 0s 62us/sample - loss: 1.1677
# Epoch 52/100
# 150/150 [==============================] - 0s 63us/sample - loss: 1.1600
# Epoch 53/100
# 150/150 [==============================] - 0s 60us/sample - loss: 1.1527
# Epoch 54/100
# 150/150 [==============================] - 0s 70us/sample - loss: 1.1454
# Epoch 55/100
# 150/150 [==============================] - 0s 65us/sample - loss: 1.1383
# Epoch 56/100
# 150/150 [==============================] - 0s 69us/sample - loss: 1.1314
# Epoch 57/100
# 150/150 [==============================] - 0s 60us/sample - loss: 1.1247
# Epoch 58/100
# 150/150 [==============================] - 0s 60us/sample - loss: 1.1184
# Epoch 59/100
# 150/150 [==============================] - 0s 73us/sample - loss: 1.1117
# Epoch 60/100
# 150/150 [==============================] - 0s 62us/sample - loss: 1.1054
# Epoch 61/100
# 150/150 [==============================] - 0s 61us/sample - loss: 1.0989
# Epoch 62/100
# 150/150 [==============================] - 0s 69us/sample - loss: 1.0929
# Epoch 63/100
# 150/150 [==============================] - 0s 64us/sample - loss: 1.0868
# Epoch 64/100
# 150/150 [==============================] - 0s 69us/sample - loss: 1.0808
# Epoch 65/100
# 150/150 [==============================] - 0s 73us/sample - loss: 1.0751
# Epoch 66/100
# 150/150 [==============================] - 0s 68us/sample - loss: 1.0695
# Epoch 67/100
# 150/150 [==============================] - 0s 73us/sample - loss: 1.0637
# Epoch 68/100
# 150/150 [==============================] - 0s 65us/sample - loss: 1.0585
# Epoch 69/100
# 150/150 [==============================] - 0s 67us/sample - loss: 1.0533
# Epoch 70/100
# 150/150 [==============================] - 0s 76us/sample - loss: 1.0481
# Epoch 71/100
# 150/150 [==============================] - 0s 78us/sample - loss: 1.0430
# Epoch 72/100
# 150/150 [==============================] - 0s 71us/sample - loss: 1.0383
# Epoch 73/100
# 150/150 [==============================] - 0s 66us/sample - loss: 1.0333
# Epoch 74/100
# 150/150 [==============================] - 0s 60us/sample - loss: 1.0288
# Epoch 75/100
# 150/150 [==============================] - 0s 59us/sample - loss: 1.0241
# Epoch 76/100
# 150/150 [==============================] - 0s 63us/sample - loss: 1.0196
# Epoch 77/100
# 150/150 [==============================] - 0s 63us/sample - loss: 1.0151
# Epoch 78/100
# 150/150 [==============================] - 0s 61us/sample - loss: 1.0106
# Epoch 79/100
# 150/150 [==============================] - 0s 54us/sample - loss: 1.0061
# Epoch 80/100
# 150/150 [==============================] - 0s 60us/sample - loss: 1.0018
# Epoch 81/100
# 150/150 [==============================] - 0s 89us/sample - loss: 0.9977
# Epoch 82/100
# 150/150 [==============================] - 0s 79us/sample - loss: 0.9937
# Epoch 83/100
# 150/150 [==============================] - 0s 84us/sample - loss: 0.9899
# Epoch 84/100
# 150/150 [==============================] - 0s 62us/sample - loss: 0.9860
# Epoch 85/100
# 150/150 [==============================] - 0s 61us/sample - loss: 0.9825
# Epoch 86/100
# 150/150 [==============================] - 0s 58us/sample - loss: 0.9787
# Epoch 87/100
# 150/150 [==============================] - 0s 63us/sample - loss: 0.9751
# Epoch 88/100
# 150/150 [==============================] - 0s 60us/sample - loss: 0.9717
# Epoch 89/100
# 150/150 [==============================] - 0s 66us/sample - loss: 0.9681
# Epoch 90/100
# 150/150 [==============================] - 0s 79us/sample - loss: 0.9647
# Epoch 91/100
# 150/150 [==============================] - 0s 64us/sample - loss: 0.9611
# Epoch 92/100
# 150/150 [==============================] - 0s 64us/sample - loss: 0.9578
# Epoch 93/100
# 150/150 [==============================] - 0s 65us/sample - loss: 0.9548
# Epoch 94/100
# 150/150 [==============================] - 0s 54us/sample - loss: 0.9514
# Epoch 95/100
# 150/150 [==============================] - 0s 51us/sample - loss: 0.9483
# Epoch 96/100
# 150/150 [==============================] - 0s 52us/sample - loss: 0.9452
# Epoch 97/100
# 150/150 [==============================] - 0s 53us/sample - loss: 0.9421
# Epoch 98/100
# 150/150 [==============================] - 0s 52us/sample - loss: 0.9391
# Epoch 99/100
# 150/150 [==============================] - 0s 50us/sample - loss: 0.9363
# Epoch 100/100
# 150/150 [==============================] - 0s 64us/sample - loss: 0.9335

# %% [markdown]
# **fit()메서드**
#
# * `validation_split=0.3` : 검증데이터 크기를  30%로 한다.
# * `history` : 히스토리 객체는 epoch마다 계산한 손실 함수 값이 저장되어 있다.
# * 훈련세트에 대한 손실 함수값은 `'loss'` 키에 담겨 있다.

# %%
epochs = np.arange(1, 100+1)
plt.plot(epochs, history.history['loss'], label='Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 함수형 API
# sequential 모델은 층을 순서대로 쌓은 것이다. 보다 복잡한 모형을 만들어야 할 때 tf.keras의 함수형 API를 사용하면 더 다양한 모델을 만들 수 있다. 함수형API를 사용하면 원하는 층을 자유롭게 조합 할 수 있다.

# %%
from tensorflow.keras import Model, Input

input = tf.keras.Input(shape=(1,))
output = tf.keras.layers.Dense(1)(input)

model = tf.keras.Model(input, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Input layer는 입력데이터를 위한 층으로 훈련할 가중치를 가지고 있지 않다.
#
# 컴파일하고 훈련하는 단계는 sequential 모델과 동일하다.

# %%
#model.compile(loss='mean_squared_error',
#              optimizer=tf.keras.optimizers.SGD(lr=0.01))

model.compile(optimizer='sgd', loss='mse')
history = model.fit(x_train, y_train, epochs=100, 
                    validation_split=0.3)
# Out:
# Train on 105 samples, validate on 45 samples
# Epoch 1/100
# 105/105 [==============================] - 0s 657us/sample - loss: 1.6704 - val_loss: 1.3690
# Epoch 2/100
# 105/105 [==============================] - 0s 84us/sample - loss: 1.5178 - val_loss: 1.2808
# Epoch 3/100
# 105/105 [==============================] - 0s 83us/sample - loss: 1.4070 - val_loss: 1.2006
# Epoch 4/100
# 105/105 [==============================] - 0s 76us/sample - loss: 1.3013 - val_loss: 1.1392
# Epoch 5/100
# 105/105 [==============================] - 0s 101us/sample - loss: 1.2227 - val_loss: 1.0920
# Epoch 6/100
# 105/105 [==============================] - 0s 84us/sample - loss: 1.1594 - val_loss: 1.0488
# Epoch 7/100
# 105/105 [==============================] - 0s 103us/sample - loss: 1.0992 - val_loss: 1.0128
# Epoch 8/100
# 105/105 [==============================] - 0s 99us/sample - loss: 1.0486 - val_loss: 0.9816
# Epoch 9/100
# 105/105 [==============================] - 0s 93us/sample - loss: 1.0022 - val_loss: 0.9562
# Epoch 10/100
# 105/105 [==============================] - 0s 85us/sample - loss: 0.9652 - val_loss: 0.9363
# Epoch 11/100
# 105/105 [==============================] - 0s 79us/sample - loss: 0.9341 - val_loss: 0.9219
# Epoch 12/100
# 105/105 [==============================] - 0s 90us/sample - loss: 0.9097 - val_loss: 0.9061
# Epoch 13/100
# 105/105 [==============================] - 0s 85us/sample - loss: 0.8831 - val_loss: 0.8953
# Epoch 14/100
# 105/105 [==============================] - 0s 85us/sample - loss: 0.8636 - val_loss: 0.8881
# Epoch 15/100
# 105/105 [==============================] - 0s 86us/sample - loss: 0.8494 - val_loss: 0.8803
# Epoch 16/100
# 105/105 [==============================] - 0s 85us/sample - loss: 0.8321 - val_loss: 0.8770
# Epoch 17/100
# 105/105 [==============================] - 0s 82us/sample - loss: 0.8196 - val_loss: 0.8740
# Epoch 18/100
# 105/105 [==============================] - 0s 85us/sample - loss: 0.8130 - val_loss: 0.8713
# Epoch 19/100
# 105/105 [==============================] - 0s 84us/sample - loss: 0.8040 - val_loss: 0.8708
# Epoch 20/100
# 105/105 [==============================] - 0s 95us/sample - loss: 0.7986 - val_loss: 0.8703
# Epoch 21/100
# 105/105 [==============================] - 0s 84us/sample - loss: 0.7946 - val_loss: 0.8711
# Epoch 22/100
# 105/105 [==============================] - 0s 92us/sample - loss: 0.7902 - val_loss: 0.8706
# Epoch 23/100
# 105/105 [==============================] - 0s 82us/sample - loss: 0.7858 - val_loss: 0.8688
# Epoch 24/100
# 105/105 [==============================] - 0s 90us/sample - loss: 0.7843 - val_loss: 0.8695
# Epoch 25/100
# 105/105 [==============================] - 0s 83us/sample - loss: 0.7816 - val_loss: 0.8692
# Epoch 26/100
# 105/105 [==============================] - 0s 90us/sample - loss: 0.7778 - val_loss: 0.8711
# Epoch 27/100
# 105/105 [==============================] - 0s 81us/sample - loss: 0.7740 - val_loss: 0.8729
# Epoch 28/100
# 105/105 [==============================] - 0s 94us/sample - loss: 0.7710 - val_loss: 0.8743
# Epoch 29/100
# 105/105 [==============================] - 0s 102us/sample - loss: 0.7700 - val_loss: 0.8742
# Epoch 30/100
# 105/105 [==============================] - 0s 104us/sample - loss: 0.7693 - val_loss: 0.8752
# Epoch 31/100
# 105/105 [==============================] - 0s 91us/sample - loss: 0.7676 - val_loss: 0.8755
# Epoch 32/100
# 105/105 [==============================] - 0s 97us/sample - loss: 0.7683 - val_loss: 0.8774
# Epoch 33/100
# 105/105 [==============================] - 0s 111us/sample - loss: 0.7639 - val_loss: 0.8767
# Epoch 34/100
# 105/105 [==============================] - 0s 154us/sample - loss: 0.7657 - val_loss: 0.8781
# Epoch 35/100
# 105/105 [==============================] - 0s 112us/sample - loss: 0.7623 - val_loss: 0.8771
# Epoch 36/100
# 105/105 [==============================] - 0s 108us/sample - loss: 0.7629 - val_loss: 0.8768
# Epoch 37/100
# 105/105 [==============================] - 0s 74us/sample - loss: 0.7617 - val_loss: 0.8784
# Epoch 38/100
# 105/105 [==============================] - 0s 98us/sample - loss: 0.7608 - val_loss: 0.8802
# Epoch 39/100
# 105/105 [==============================] - 0s 125us/sample - loss: 0.7610 - val_loss: 0.8807
# Epoch 40/100
# 105/105 [==============================] - 0s 145us/sample - loss: 0.7597 - val_loss: 0.8826
# Epoch 41/100
# 105/105 [==============================] - 0s 93us/sample - loss: 0.7603 - val_loss: 0.8874
# Epoch 42/100
# 105/105 [==============================] - 0s 95us/sample - loss: 0.7595 - val_loss: 0.8856
# Epoch 43/100
# 105/105 [==============================] - 0s 95us/sample - loss: 0.7600 - val_loss: 0.8865
# Epoch 44/100
# 105/105 [==============================] - 0s 115us/sample - loss: 0.7579 - val_loss: 0.8877
# Epoch 45/100
# 105/105 [==============================] - 0s 101us/sample - loss: 0.7577 - val_loss: 0.8872
# Epoch 46/100
# 105/105 [==============================] - 0s 135us/sample - loss: 0.7585 - val_loss: 0.8927
# Epoch 47/100
# 105/105 [==============================] - 0s 90us/sample - loss: 0.7575 - val_loss: 0.8921
# Epoch 48/100
# 105/105 [==============================] - 0s 99us/sample - loss: 0.7576 - val_loss: 0.8913
# Epoch 49/100
# 105/105 [==============================] - 0s 131us/sample - loss: 0.7574 - val_loss: 0.8907
# Epoch 50/100
# 105/105 [==============================] - 0s 112us/sample - loss: 0.7573 - val_loss: 0.8975
# Epoch 51/100
# 105/105 [==============================] - 0s 119us/sample - loss: 0.7570 - val_loss: 0.8971
# Epoch 52/100
# 105/105 [==============================] - 0s 109us/sample - loss: 0.7570 - val_loss: 0.8958
# Epoch 53/100
# 105/105 [==============================] - 0s 132us/sample - loss: 0.7561 - val_loss: 0.8968
# Epoch 54/100
# 105/105 [==============================] - 0s 92us/sample - loss: 0.7563 - val_loss: 0.8953
# Epoch 55/100
# 105/105 [==============================] - 0s 106us/sample - loss: 0.7564 - val_loss: 0.8952
# Epoch 56/100
# 105/105 [==============================] - 0s 101us/sample - loss: 0.7570 - val_loss: 0.8955
# Epoch 57/100
# 105/105 [==============================] - 0s 105us/sample - loss: 0.7564 - val_loss: 0.8966
# Epoch 58/100
# 105/105 [==============================] - 0s 106us/sample - loss: 0.7568 - val_loss: 0.8956
# Epoch 59/100
# 105/105 [==============================] - 0s 97us/sample - loss: 0.7563 - val_loss: 0.8926
# Epoch 60/100
# 105/105 [==============================] - 0s 100us/sample - loss: 0.7570 - val_loss: 0.8963
# Epoch 61/100
# 105/105 [==============================] - 0s 102us/sample - loss: 0.7583 - val_loss: 0.8979
# Epoch 62/100
# 105/105 [==============================] - 0s 134us/sample - loss: 0.7572 - val_loss: 0.8968
# Epoch 63/100
# 105/105 [==============================] - 0s 111us/sample - loss: 0.7574 - val_loss: 0.8934
# Epoch 64/100
# 105/105 [==============================] - 0s 103us/sample - loss: 0.7575 - val_loss: 0.8968
# Epoch 65/100
# 105/105 [==============================] - 0s 112us/sample - loss: 0.7566 - val_loss: 0.8965
# Epoch 66/100
# 105/105 [==============================] - 0s 105us/sample - loss: 0.7604 - val_loss: 0.8944
# Epoch 67/100
# 105/105 [==============================] - 0s 132us/sample - loss: 0.7569 - val_loss: 0.8978
# Epoch 68/100
# 105/105 [==============================] - 0s 93us/sample - loss: 0.7581 - val_loss: 0.8982
# Epoch 69/100
# 105/105 [==============================] - 0s 104us/sample - loss: 0.7579 - val_loss: 0.8990
# Epoch 70/100
# 105/105 [==============================] - 0s 121us/sample - loss: 0.7560 - val_loss: 0.8984
# Epoch 71/100
# 105/105 [==============================] - 0s 122us/sample - loss: 0.7560 - val_loss: 0.8980
# Epoch 72/100
# 105/105 [==============================] - 0s 90us/sample - loss: 0.7558 - val_loss: 0.8974
# Epoch 73/100
# 105/105 [==============================] - 0s 86us/sample - loss: 0.7561 - val_loss: 0.8973
# Epoch 74/100
# 105/105 [==============================] - 0s 102us/sample - loss: 0.7563 - val_loss: 0.8971
# Epoch 75/100
# 105/105 [==============================] - 0s 96us/sample - loss: 0.7564 - val_loss: 0.8968
# Epoch 76/100
# 105/105 [==============================] - 0s 145us/sample - loss: 0.7564 - val_loss: 0.9024
# Epoch 77/100
# 105/105 [==============================] - 0s 92us/sample - loss: 0.7563 - val_loss: 0.9027
# Epoch 78/100
# 105/105 [==============================] - 0s 101us/sample - loss: 0.7562 - val_loss: 0.9017
# Epoch 79/100
# 105/105 [==============================] - 0s 86us/sample - loss: 0.7560 - val_loss: 0.9033
# Epoch 80/100
# 105/105 [==============================] - 0s 90us/sample - loss: 0.7564 - val_loss: 0.9029
# Epoch 81/100
# 105/105 [==============================] - 0s 89us/sample - loss: 0.7564 - val_loss: 0.9003
# Epoch 82/100
# 105/105 [==============================] - 0s 89us/sample - loss: 0.7559 - val_loss: 0.9023
# Epoch 83/100
# 105/105 [==============================] - 0s 99us/sample - loss: 0.7563 - val_loss: 0.9069
# Epoch 84/100
# 105/105 [==============================] - 0s 112us/sample - loss: 0.7559 - val_loss: 0.9062
# Epoch 85/100
# 105/105 [==============================] - 0s 159us/sample - loss: 0.7578 - val_loss: 0.9049
# Epoch 86/100
# 105/105 [==============================] - 0s 120us/sample - loss: 0.7569 - val_loss: 0.8996
# Epoch 87/100
# 105/105 [==============================] - 0s 95us/sample - loss: 0.7565 - val_loss: 0.8983
# Epoch 88/100
# 105/105 [==============================] - 0s 123us/sample - loss: 0.7564 - val_loss: 0.8961
# Epoch 89/100
# 105/105 [==============================] - 0s 155us/sample - loss: 0.7563 - val_loss: 0.8984
# Epoch 90/100
# 105/105 [==============================] - 0s 86us/sample - loss: 0.7562 - val_loss: 0.9016
# Epoch 91/100
# 105/105 [==============================] - 0s 119us/sample - loss: 0.7562 - val_loss: 0.9045
# Epoch 92/100
# 105/105 [==============================] - 0s 100us/sample - loss: 0.7573 - val_loss: 0.9026
# Epoch 93/100
# 105/105 [==============================] - 0s 107us/sample - loss: 0.7562 - val_loss: 0.9034
# Epoch 94/100
# 105/105 [==============================] - 0s 86us/sample - loss: 0.7575 - val_loss: 0.9020
# Epoch 95/100
# 105/105 [==============================] - 0s 106us/sample - loss: 0.7571 - val_loss: 0.9019
# Epoch 96/100
# 105/105 [==============================] - 0s 112us/sample - loss: 0.7569 - val_loss: 0.8977
# Epoch 97/100
# 105/105 [==============================] - 0s 101us/sample - loss: 0.7568 - val_loss: 0.8984
# Epoch 98/100
# 105/105 [==============================] - 0s 160us/sample - loss: 0.7565 - val_loss: 0.8952
# Epoch 99/100
# 105/105 [==============================] - 0s 92us/sample - loss: 0.7585 - val_loss: 0.8962
# Epoch 100/100
# 105/105 [==============================] - 0s 111us/sample - loss: 0.7565 - val_loss: 0.8926

# %%
plt.plot(epochs, history.history['loss'], label='Training loss')
plt.plot(epochs, history.history['val_loss'], label='Validation loss') # validation loss
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### tf.keras 모델의 저장과 복원

# %%
model.save_weights('simple_weights.h5')

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, input_dim=1))
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.SGD(lr=0.01))

model.load_weights('simple_weights.h5')

# %%
model.evaluate(x_test, y_test)
# Out:
# 50/50 [==============================] - 0s 475us/sample - loss: 0.9514
# 0.9514367270469666

# %%
model.save('simple_model.h5')

# %%
model = tf.keras.models.load_model('simple_model.h5')
model.evaluate(x_test, y_test)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 50/50 [==============================] - 0s 380us/sample - loss: 0.9514
# 0.9514367270469666

# %%
x_arr = np.arange(-2, 2, 0.1)
y_arr = model.predict(x_arr)

plt.figure()
plt.plot(x_train, y_train, 'bo')
plt.plot(x_test, y_test, 'bo', alpha=0.3)
plt.plot(x_arr, y_arr, '-r', lw=3)
plt.show()
